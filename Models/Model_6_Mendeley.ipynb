# %%
import os
import json
import time
import copy
import random
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
from torch.amp import autocast, GradScaler
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms
import torch.nn.functional as F

from sklearn.metrics import (
    accuracy_score,
    precision_recall_fscore_support,
    matthews_corrcoef,
    balanced_accuracy_score,
    confusion_matrix,
    classification_report
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
SEED = 2912

def seed_everything(seed=SEED):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

seed_everything()
torch.backends.cudnn.benchmark = True

# %%
DATASET_PATH = "../Dataset"
DATASET_NAME = "Mendeley_Dataset"

IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 100
LR = 3e-4
ACCUM_STEPS = 2
PATIENCE = 15
MIN_DELTA = 0.001

OUTPUT_DIR = f"../Results/{DATASET_NAME}/Model_6"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.8, 0.9)),
    transforms.RandomVerticalFlip(),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(40),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    transforms.ToTensor()
])

val_transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor()
])

# %%
full_dataset = datasets.ImageFolder(f"{DATASET_PATH}/{DATASET_NAME}")

class_names = full_dataset.classes
num_classes = len(class_names)

train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size

train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

train_dataset.dataset.transform = train_transform
val_dataset.dataset.transform = val_transform

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=4,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=4,
    pin_memory=True
)

print(class_names)
print(num_classes)
# Out:
# ['Bacteria', 'Fungi', 'Healthy', 'Nematode', 'Pest', 'Phytopthora', 'Virus']
# 7

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class HybridCACNet(nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        # CNN backbone
        self.conv1 = self._block(3, 32)
        self.conv2 = self._block(32, 64)
        self.conv3 = self._block(64, 96)
        self.conv4 = self._block(96, 128)

        # Attention
        self.attn = nn.MultiheadAttention(
            embed_dim=128,
            num_heads=2,
            batch_first=True,
            dropout=0.2
        )

        self.norm1 = nn.LayerNorm(128)

        # Feed Forward
        self.ffn = nn.Sequential(
            nn.Linear(128, 256),
            nn.GELU(),
            nn.Dropout(0.3),
            nn.Linear(256, 128)
        )

        self.norm2 = nn.LayerNorm(128)

        self.dropout = nn.Dropout(0.3)

        self.classifier = nn.Sequential(
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.35),
            nn.Linear(64, num_classes)
        )

    def _block(self, in_c, out_c):
        return nn.Sequential(
            nn.Conv2d(in_c, out_c, 3, padding=1),
            nn.BatchNorm2d(out_c),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

    def forward(self, x):

        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)

        # Flatten to tokens
        x = x.flatten(2).transpose(1, 2)

        # Attention block
        attn_out, _ = self.attn(x, x, x)
        x = self.norm1(x + self.dropout(attn_out))

        # FFN block
        ffn_out = self.ffn(x)
        x = self.norm2(x + self.dropout(ffn_out))

        # Global average pooling over tokens
        x = x.mean(dim=1)

        return self.classifier(x)

# %%
model = HybridCACNet(num_classes).to(device)

# %%
# Total parameters
total_params = sum(p.numel() for p in model.parameters())

# Trainable parameters
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"Total Parameters: {total_params:,}")
print(f"Trainable Parameters: {trainable_params:,}")
# Out:
# Total Parameters: 327,335
# Trainable Parameters: 327,335

# %%
from torchinfo import summary

summary(model, input_size=(1, 3, 224, 224))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# HybridCACNet                             [1, 7]                    --
# ├─Sequential: 1-1                        [1, 32, 112, 112]         --
# │    └─Conv2d: 2-1                       [1, 32, 224, 224]         896
# │    └─BatchNorm2d: 2-2                  [1, 32, 224, 224]         64
# │    └─ReLU: 2-3                         [1, 32, 224, 224]         --
# │    └─MaxPool2d: 2-4                    [1, 32, 112, 112]         --
# ├─Sequential: 1-2                        [1, 64, 56, 56]           --
# │    └─Conv2d: 2-5                       [1, 64, 112, 112]         18,496
# │    └─BatchNorm2d: 2-6                  [1, 64, 112, 112]         128
# │    └─ReLU: 2-7                         [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-8                    [1, 64, 56, 56]           --
# ├─Sequential: 1-3                        [1, 96, 28, 28]           --
# │    └─Conv2d: 2-9                       [1, 96, 56, 56]           55,392
# │    └─BatchNorm2d: 2-10                 [1, 96, 56, 56]           192
# │    └─ReLU: 2-11                        [1, 96, 56, 56]           --
# │    └─MaxPool2d: 2-12                   [1, 96, 28, 28]           --
# ├─Sequential: 1-4                        [1, 128, 14, 14]          --
# │    └─Conv2d: 2-13                      [1, 128, 28, 28]          110,720
# │    └─BatchNorm2d: 2-14                 [1, 128, 28, 28]          256
# │    └─ReLU: 2-15                        [1, 128, 28, 28]          --
# │    └─MaxPool2d: 2-16                   [1, 128, 14, 14]          --
# ├─MultiheadAttention: 1-5                [1, 196, 128]             66,048
# ├─Dropout: 1-6                           [1, 196, 128]             --
# ├─LayerNorm: 1-7                         [1, 196, 128]             256
# ├─Sequential: 1-8                        [1, 196, 128]             --
# │    └─Linear: 2-17                      [1, 196, 256]             33,024
# │    └─GELU: 2-18                        [1, 196, 256]             --
# │    └─Dropout: 2-19                     [1, 196, 256]             --
# │    └─Linear: 2-20                      [1, 196, 128]             32,896
# ├─Dropout: 1-9                           [1, 196, 128]             --
# ├─LayerNorm: 1-10                        [1, 196, 128]             256
# ├─Sequential: 1-11                       [1, 7]                    --
# │    └─Linear: 2-21                      [1, 64]                   8,256
# │    └─ReLU: 2-22                        [1, 64]                   --
# │    └─Dropout: 2-23                     [1, 64]                   --
# │    └─Linear: 2-24                      [1, 7]                    455
# ==========================================================================================
# Total params: 327,335
# Trainable params: 327,335
# Non-trainable params: 0
# Total mult-adds (M): 537.56
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 45.96
# Params size (MB): 1.05
# Estimated Total Size (MB): 47.61
# ==========================================================================================

# %%
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=LR,
    weight_decay=1e-4
)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=0.2,
    patience=3
)

scaler = GradScaler()

# %%
def evaluate(model, loader):
    model.eval()

    all_preds = []
    all_labels = []
    total_loss = 0

    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)

            with autocast(device_type=device.type):
                outputs = model(images)
                loss = criterion(outputs, labels)

            total_loss += loss.item()

            preds = outputs.argmax(1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    acc = accuracy_score(all_labels, all_preds)

    return total_loss/len(loader), acc, all_labels, all_preds

# %%
history = {
    "train_loss": [],
    "val_loss": [],
    "train_acc": [],
    "val_acc": []
}

best_acc = 0
best_weights = copy.deepcopy(model.state_dict())
early_counter = 0

# %%
for epoch in range(EPOCHS):

    model.train()

    running_loss = 0
    correct = 0
    total = 0

    optimizer.zero_grad()

    for i, (images, labels) in enumerate(train_loader):

        images, labels = images.to(device), labels.to(device)

        with autocast(device_type=device.type):
            outputs = model(images)
            loss = criterion(outputs, labels) / ACCUM_STEPS

        scaler.scale(loss).backward()

        if (i+1) % ACCUM_STEPS == 0:
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()

        running_loss += loss.item()*ACCUM_STEPS

        preds = outputs.argmax(1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    train_loss = running_loss / len(train_loader)
    train_acc = correct / total

    val_loss, val_acc, _, _ = evaluate(model, val_loader)

    scheduler.step(val_loss)

    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_acc"].append(train_acc)
    history["val_acc"].append(val_acc)
    
    print(f"Epoch {epoch+1}/{EPOCHS}")
    print(f"LR: {optimizer.param_groups[0]['lr']:.2e}")
    print(f"Early Counter: {early_counter} | Best Val Acc: {best_acc:.4f}")
    print(f"Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f}")
    print(f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")
    print("-"*30)

    if val_acc > best_acc + MIN_DELTA:
        best_acc = val_acc
        best_weights = copy.deepcopy(model.state_dict())
        torch.save(best_weights, f"{OUTPUT_DIR}/best_model.pth")
        early_counter = 0
    else:
        early_counter += 1

    if early_counter >= PATIENCE:
        print("Early stopping")
        break
# Out:
# Epoch 1/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.0000
# Train Acc: 0.3276 | Val Acc: 0.4172
# Train Loss: 1.7624 | Val Loss: 1.6211
# ------------------------------
# Epoch 2/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.4172
# Train Acc: 0.4195 | Val Acc: 0.4448
# Train Loss: 1.6003 | Val Loss: 1.5543
# ------------------------------
# Epoch 3/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.4448
# Train Acc: 0.4569 | Val Acc: 0.4367
# Train Loss: 1.5157 | Val Loss: 1.5764
# ------------------------------
# Epoch 4/100
# LR: 3.00e-04
# Early Counter: 1 | Best Val Acc: 0.4448
# Train Acc: 0.4902 | Val Acc: 0.5584
# Train Loss: 1.4508 | Val Loss: 1.3872
# ------------------------------
# Epoch 5/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.5584
# Train Acc: 0.5045 | Val Acc: 0.5731
# Train Loss: 1.4123 | Val Loss: 1.3658
# ------------------------------
# Epoch 6/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.5731
# Train Acc: 0.5394 | Val Acc: 0.4318
# Train Loss: 1.3620 | Val Loss: 1.6050
# ------------------------------
# Epoch 7/100
# LR: 3.00e-04
# Early Counter: 1 | Best Val Acc: 0.5731
# Train Acc: 0.5492 | Val Acc: 0.4870
# Train Loss: 1.3418 | Val Loss: 1.4328
# ------------------------------
# Epoch 8/100
# LR: 3.00e-04
# Early Counter: 2 | Best Val Acc: 0.5731
# Train Acc: 0.5898 | Val Acc: 0.5877
# Train Loss: 1.3005 | Val Loss: 1.3199
# ------------------------------
# Epoch 9/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.5877
# Train Acc: 0.5992 | Val Acc: 0.4578
# Train Loss: 1.2554 | Val Loss: 1.6003
# ------------------------------
# Epoch 10/100
# LR: 3.00e-04
# Early Counter: 1 | Best Val Acc: 0.5877
# Train Acc: 0.6033 | Val Acc: 0.6185
# Train Loss: 1.2499 | Val Loss: 1.2282
# ------------------------------
# Epoch 11/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.6185
# Train Acc: 0.6297 | Val Acc: 0.5260
# Train Loss: 1.1945 | Val Loss: 1.3831
# ------------------------------
# Epoch 12/100
# LR: 3.00e-04
# Early Counter: 1 | Best Val Acc: 0.6185
# Train Acc: 0.6419 | Val Acc: 0.6347
# Train Loss: 1.1957 | Val Loss: 1.1801
# ------------------------------
# Epoch 13/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.6347
# Train Acc: 0.6683 | Val Acc: 0.5860
# Train Loss: 1.1400 | Val Loss: 1.2985
# ------------------------------
# Epoch 14/100
# LR: 3.00e-04
# Early Counter: 1 | Best Val Acc: 0.6347
# Train Acc: 0.6890 | Val Acc: 0.6380
# Train Loss: 1.1053 | Val Loss: 1.2015
# ------------------------------
# Epoch 15/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.6380
# Train Acc: 0.7057 | Val Acc: 0.6104
# Train Loss: 1.0848 | Val Loss: 1.2679
# ------------------------------
# Epoch 16/100
# LR: 6.00e-05
# Early Counter: 1 | Best Val Acc: 0.6380
# Train Acc: 0.7134 | Val Acc: 0.6006
# Train Loss: 1.0576 | Val Loss: 1.3558
# ------------------------------
# Epoch 17/100
# LR: 6.00e-05
# Early Counter: 2 | Best Val Acc: 0.6380
# Train Acc: 0.7663 | Val Acc: 0.6818
# Train Loss: 0.9570 | Val Loss: 1.1509
# ------------------------------
# Epoch 18/100
# LR: 6.00e-05
# Early Counter: 0 | Best Val Acc: 0.6818
# Train Acc: 0.8122 | Val Acc: 0.6510
# Train Loss: 0.9000 | Val Loss: 1.2066
# ------------------------------
# Epoch 19/100
# LR: 6.00e-05
# Early Counter: 1 | Best Val Acc: 0.6818
# Train Acc: 0.8297 | Val Acc: 0.6494
# Train Loss: 0.8635 | Val Loss: 1.2289
# ------------------------------
# Epoch 20/100
# LR: 6.00e-05
# Early Counter: 2 | Best Val Acc: 0.6818
# Train Acc: 0.8313 | Val Acc: 0.6591
# Train Loss: 0.8521 | Val Loss: 1.1908
# ------------------------------
# Epoch 21/100
# LR: 1.20e-05
# Early Counter: 3 | Best Val Acc: 0.6818
# Train Acc: 0.8492 | Val Acc: 0.6510
# Train Loss: 0.8281 | Val Loss: 1.2552
# ------------------------------
# Epoch 22/100
# LR: 1.20e-05
# Early Counter: 4 | Best Val Acc: 0.6818
# Train Acc: 0.8646 | Val Acc: 0.6721
# Train Loss: 0.7977 | Val Loss: 1.2068
# ------------------------------
# Epoch 23/100
# LR: 1.20e-05
# Early Counter: 5 | Best Val Acc: 0.6818
# Train Acc: 0.8724 | Val Acc: 0.6705
# Train Loss: 0.7864 | Val Loss: 1.2224
# ------------------------------
# Epoch 24/100
# LR: 1.20e-05
# Early Counter: 6 | Best Val Acc: 0.6818
# Train Acc: 0.8699 | Val Acc: 0.6737
# Train Loss: 0.7900 | Val Loss: 1.2221
# ------------------------------
# Epoch 25/100
# LR: 2.40e-06
# Early Counter: 7 | Best Val Acc: 0.6818
# Train Acc: 0.8748 | Val Acc: 0.6672
# Train Loss: 0.7713 | Val Loss: 1.2219
# ------------------------------
# Epoch 26/100
# LR: 2.40e-06
# Early Counter: 8 | Best Val Acc: 0.6818
# Train Acc: 0.8801 | Val Acc: 0.6688
# Train Loss: 0.7759 | Val Loss: 1.2267
# ------------------------------
# Epoch 27/100
# LR: 2.40e-06
# Early Counter: 9 | Best Val Acc: 0.6818
# Train Acc: 0.8768 | Val Acc: 0.6672
# Train Loss: 0.7771 | Val Loss: 1.2265
# ------------------------------
# Epoch 28/100
# LR: 2.40e-06
# Early Counter: 10 | Best Val Acc: 0.6818
# Train Acc: 0.8841 | Val Acc: 0.6705
# Train Loss: 0.7694 | Val Loss: 1.2226
# ------------------------------
# Epoch 29/100
# LR: 4.80e-07
# Early Counter: 11 | Best Val Acc: 0.6818
# Train Acc: 0.8890 | Val Acc: 0.6656
# Train Loss: 0.7637 | Val Loss: 1.2276
# ------------------------------
# Epoch 30/100
# LR: 4.80e-07
# Early Counter: 12 | Best Val Acc: 0.6818
# Train Acc: 0.8854 | Val Acc: 0.6721
# Train Loss: 0.7671 | Val Loss: 1.2215
# ------------------------------
# Epoch 31/100
# LR: 4.80e-07
# Early Counter: 13 | Best Val Acc: 0.6818
# Train Acc: 0.8886 | Val Acc: 0.6672
# Train Loss: 0.7581 | Val Loss: 1.2272
# ------------------------------
# Epoch 32/100
# LR: 4.80e-07
# Early Counter: 14 | Best Val Acc: 0.6818
# Train Acc: 0.8809 | Val Acc: 0.6672
# Train Loss: 0.7667 | Val Loss: 1.2274
# ------------------------------
# Early stopping

# %%
model.load_state_dict(best_weights)

val_loss, val_acc, y_true, y_pred = evaluate(model, val_loader)

# %%
precision, recall, f1, _ = precision_recall_fscore_support(
    y_true, y_pred, average='weighted'
)

mcc = matthews_corrcoef(y_true, y_pred)
bal_acc = balanced_accuracy_score(y_true, y_pred)

cm = confusion_matrix(y_true, y_pred)

report = classification_report(
    y_true,
    y_pred,
    target_names=class_names
)

results = {
    "accuracy": val_acc,
    "precision": precision,
    "recall": recall,
    "f1": f1,
    "mcc": mcc,
    "balanced_accuracy": bal_acc
}

print(results)
print(report)
# Out:
# {'accuracy': 0.6818181818181818, 'precision': 0.6744495256285377, 'recall': 0.6818181818181818, 'f1': 0.6730844985785969, 'mcc': 0.6108653664108602, 'balanced_accuracy': 0.6524966295222726}
#               precision    recall  f1-score   support
#
#     Bacteria       0.82      0.92      0.87       126
#        Fungi       0.62      0.64      0.63       139
#      Healthy       0.53      0.24      0.33        42
#     Nematode       0.64      0.82      0.72        11
#         Pest       0.52      0.54      0.53       112
#  Phytopthora       0.70      0.61      0.65        71
#        Virus       0.77      0.80      0.78       115
#
#     accuracy                           0.68       616
#    macro avg       0.66      0.65      0.64       616
# weighted avg       0.67      0.68      0.67       616

# %%
pd.DataFrame(history).to_csv(f"{OUTPUT_DIR}/history.csv", index=False)
pd.DataFrame([results]).to_csv(f"{OUTPUT_DIR}/summary.csv", index=False)

with open(f"{OUTPUT_DIR}/results.json","w") as f:
    json.dump(results,f,indent=4)

with open(f"{OUTPUT_DIR}/report.txt","w") as f:
    f.write(report)

# %%
plt.figure(figsize=(12,5))
plt.plot(history["train_loss"], label="Train")
plt.plot(history["val_loss"], label="Val")
plt.legend()
plt.savefig(f"{OUTPUT_DIR}/loss_curve.png")
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.plot(history["train_acc"], label="Train")
plt.plot(history["val_acc"], label="Val")
plt.legend()
plt.savefig(f"{OUTPUT_DIR}/acc_curve.png")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    xticklabels=class_names,
    yticklabels=class_names
)
plt.savefig(f"{OUTPUT_DIR}/confusion_matrix.png")
plt.show()
