# %%
import os
import json
import time
import copy
import random
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
from torch.amp import autocast, GradScaler
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms
import torch.nn.functional as F

from sklearn.metrics import (
    accuracy_score,
    precision_recall_fscore_support,
    matthews_corrcoef,
    balanced_accuracy_score,
    confusion_matrix,
    classification_report
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
SEED = 2912

def seed_everything(seed=SEED):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

seed_everything()
torch.backends.cudnn.benchmark = True

# %%
DATASET_PATH = "../Dataset"
DATASET_NAME = "Mendeley_Dataset"

IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 100
LR = 3e-4
ACCUM_STEPS = 2
PATIENCE = 15
MIN_DELTA = 0.001

OUTPUT_DIR = f"../Results/{DATASET_NAME}/Model_7"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
def mixup_data(x, y, alpha=0.2):
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1.0

    batch_size = x.size(0)
    index = torch.randperm(batch_size, device=x.device)

    mixed_x = lam * x + (1 - lam) * x[index]
    y_a, y_b = y, y[index]

    return mixed_x, y_a, y_b, lam

# %%
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.8, 0.9)),
    transforms.RandomVerticalFlip(),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(40),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    transforms.ToTensor()
])

val_transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor()
])

# %%
full_dataset = datasets.ImageFolder(f"{DATASET_PATH}/{DATASET_NAME}")

class_names = full_dataset.classes
num_classes = len(class_names)

train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size

train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

train_dataset.dataset.transform = train_transform
val_dataset.dataset.transform = val_transform

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=4,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=4,
    pin_memory=True
)

print(class_names)
print(num_classes)
# Out:
# ['Bacteria', 'Fungi', 'Healthy', 'Nematode', 'Pest', 'Phytopthora', 'Virus']
# 7

# %%
class CACNet(nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.conv1 = self._block(3, 32)
        self.conv2 = self._block(32, 64)
        self.conv3 = self._block(64, 96)
        self.conv4 = self._block(96, 128)

        # Residual projection
        self.proj = nn.Conv2d(96, 128, kernel_size=1)

        # Conv3 -> Conv4 attention
        self.proj_c3 = nn.Conv2d(96, 128, kernel_size=1)

        self.attn = nn.MultiheadAttention(
            embed_dim=128,
            num_heads=4,
            batch_first=True,
            dropout=0.2
        )

        self.gap = nn.AdaptiveAvgPool1d(1)

        self.fc = nn.Sequential(
            nn.Linear(128, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.6)
        )

        self.classifier = nn.Linear(128, num_classes)

    def _block(self, in_c, out_c):
        return nn.Sequential(
            nn.Conv2d(in_c, out_c, 3, padding=1),
            nn.BatchNorm2d(out_c),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

    def forward(self, x):

        f1 = self.conv1(x)
        f2 = self.conv2(f1)
        f3 = self.conv3(f2)

        # Conv4 + residual
        f4 = self.conv4(f3)
        f4 = f4 + F.interpolate(
            self.proj(f3),
            size=f4.shape[-2:]
        )

        # Cross-attention: Conv4 queries Conv3
        c3 = F.interpolate(
            self.proj_c3(f3),
            size=f4.shape[-2:]
        )

        q = f4.flatten(2).transpose(1, 2)
        kv = c3.flatten(2).transpose(1, 2)

        attn_out, _ = self.attn(q, kv, kv)

        pooled = attn_out.transpose(1, 2)
        pooled = self.gap(pooled).squeeze(-1)

        x = self.fc(pooled)

        return self.classifier(x)

# %%
model = CACNet(num_classes).to(device)

# %%
# Total parameters
total_params = sum(p.numel() for p in model.parameters())

# Trainable parameters
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"Total Parameters: {total_params:,}")
print(f"Trainable Parameters: {trainable_params:,}")
# Out:
# Total Parameters: 294,695
# Trainable Parameters: 294,695

# %%
from torchinfo import summary

summary(model, input_size=(1, 3, 224, 224))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CACNet                                   [1, 7]                    --
# ├─Sequential: 1-1                        [1, 32, 112, 112]         --
# │    └─Conv2d: 2-1                       [1, 32, 224, 224]         896
# │    └─BatchNorm2d: 2-2                  [1, 32, 224, 224]         64
# │    └─ReLU: 2-3                         [1, 32, 224, 224]         --
# │    └─MaxPool2d: 2-4                    [1, 32, 112, 112]         --
# ├─Sequential: 1-2                        [1, 64, 56, 56]           --
# │    └─Conv2d: 2-5                       [1, 64, 112, 112]         18,496
# │    └─BatchNorm2d: 2-6                  [1, 64, 112, 112]         128
# │    └─ReLU: 2-7                         [1, 64, 112, 112]         --
# │    └─MaxPool2d: 2-8                    [1, 64, 56, 56]           --
# ├─Sequential: 1-3                        [1, 96, 28, 28]           --
# │    └─Conv2d: 2-9                       [1, 96, 56, 56]           55,392
# │    └─BatchNorm2d: 2-10                 [1, 96, 56, 56]           192
# │    └─ReLU: 2-11                        [1, 96, 56, 56]           --
# │    └─MaxPool2d: 2-12                   [1, 96, 28, 28]           --
# ├─Sequential: 1-4                        [1, 128, 14, 14]          --
# │    └─Conv2d: 2-13                      [1, 128, 28, 28]          110,720
# │    └─BatchNorm2d: 2-14                 [1, 128, 28, 28]          256
# │    └─ReLU: 2-15                        [1, 128, 28, 28]          --
# │    └─MaxPool2d: 2-16                   [1, 128, 14, 14]          --
# ├─Conv2d: 1-5                            [1, 128, 28, 28]          12,416
# ├─Conv2d: 1-6                            [1, 128, 28, 28]          12,416
# ├─MultiheadAttention: 1-7                [1, 196, 128]             66,048
# ├─AdaptiveAvgPool1d: 1-8                 [1, 128, 1]               --
# ├─Sequential: 1-9                        [1, 128]                  --
# │    └─Linear: 2-17                      [1, 128]                  16,512
# │    └─BatchNorm1d: 2-18                 [1, 128]                  256
# │    └─ReLU: 2-19                        [1, 128]                  --
# │    └─Dropout: 2-20                     [1, 128]                  --
# ├─Linear: 1-10                           [1, 7]                    903
# ==========================================================================================
# Total params: 294,695
# Trainable params: 294,695
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 556.97
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 46.57
# Params size (MB): 0.91
# Estimated Total Size (MB): 48.08
# ==========================================================================================

# %%
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=LR,
    weight_decay=1e-4
)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=0.2,
    patience=3
)

scaler = GradScaler()

# %%
def evaluate(model, loader):
    model.eval()

    all_preds = []
    all_labels = []
    total_loss = 0

    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)

            with autocast(device_type=device.type):
                outputs = model(images)
                loss = criterion(outputs, labels)

            total_loss += loss.item()

            preds = outputs.argmax(1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    acc = accuracy_score(all_labels, all_preds)

    return total_loss/len(loader), acc, all_labels, all_preds

# %%
history = {
    "train_loss": [],
    "val_loss": [],
    "train_acc": [],
    "val_acc": []
}

best_acc = 0
best_weights = copy.deepcopy(model.state_dict())
early_counter = 0

# %%
for epoch in range(EPOCHS):

    model.train()

    running_loss = 0
    correct = 0
    total = 0

    optimizer.zero_grad()

    for i, (images, labels) in enumerate(train_loader):

        images, labels = images.to(device), labels.to(device)

        # Apply MixUp
        mixed_images, targets_a, targets_b, lam = mixup_data(
            images,
            labels,
            alpha=0.2
        )

        with autocast(device_type=device.type):
            outputs = model(mixed_images)

            loss = (
                lam * criterion(outputs, targets_a)
                + (1 - lam) * criterion(outputs, targets_b)
            ) / ACCUM_STEPS

        scaler.scale(loss).backward()

        if (i+1) % ACCUM_STEPS == 0:
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()

        running_loss += loss.item()*ACCUM_STEPS

        preds = outputs.argmax(1)

        correct += (
            lam * (preds == targets_a).sum().item()
            + (1 - lam) * (preds == targets_b).sum().item()
        )

        total += labels.size(0)
    
    if len(train_loader) % ACCUM_STEPS != 0:
        scaler.step(optimizer)
        scaler.update()
        optimizer.zero_grad()

    train_loss = running_loss / len(train_loader)
    train_acc = correct / total

    val_loss, val_acc, _, _ = evaluate(model, val_loader)

    scheduler.step(val_loss)

    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_acc"].append(train_acc)
    history["val_acc"].append(val_acc)
    
    print(f"Epoch {epoch+1}/{EPOCHS}")
    print(f"LR: {optimizer.param_groups[0]['lr']:.2e}")
    print(f"Early Counter: {early_counter} | Best Val Acc: {best_acc:.4f}")
    print(f"Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f}")
    print(f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")
    print("-"*30)

    if val_acc > best_acc + MIN_DELTA:
        best_acc = val_acc
        best_weights = copy.deepcopy(model.state_dict())
        torch.save(best_weights, f"{OUTPUT_DIR}/best_model.pth")
        early_counter = 0
    else:
        early_counter += 1

    if early_counter >= PATIENCE:
        print("Early stopping")
        break
# Out:
# Epoch 1/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.0000
# Train Acc: 0.2755 | Val Acc: 0.4351
# Train Loss: 1.8835 | Val Loss: 1.6185
# ------------------------------
# Epoch 2/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.4351
# Train Acc: 0.3792 | Val Acc: 0.4610
# Train Loss: 1.7012 | Val Loss: 1.5164
# ------------------------------
# Epoch 3/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.4610
# Train Acc: 0.4088 | Val Acc: 0.4351
# Train Loss: 1.6344 | Val Loss: 1.5820
# ------------------------------
# Epoch 4/100
# LR: 3.00e-04
# Early Counter: 1 | Best Val Acc: 0.4610
# Train Acc: 0.4245 | Val Acc: 0.5341
# Train Loss: 1.5906 | Val Loss: 1.3966
# ------------------------------
# Epoch 5/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.5341
# Train Acc: 0.4443 | Val Acc: 0.5308
# Train Loss: 1.5701 | Val Loss: 1.4192
# ------------------------------
# Epoch 6/100
# LR: 3.00e-04
# Early Counter: 1 | Best Val Acc: 0.5341
# Train Acc: 0.4628 | Val Acc: 0.5714
# Train Loss: 1.5273 | Val Loss: 1.3460
# ------------------------------
# Epoch 7/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.5714
# Train Acc: 0.4937 | Val Acc: 0.5503
# Train Loss: 1.4975 | Val Loss: 1.3856
# ------------------------------
# Epoch 8/100
# LR: 3.00e-04
# Early Counter: 1 | Best Val Acc: 0.5714
# Train Acc: 0.4796 | Val Acc: 0.5779
# Train Loss: 1.4971 | Val Loss: 1.3428
# ------------------------------
# Epoch 9/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.5779
# Train Acc: 0.5164 | Val Acc: 0.5860
# Train Loss: 1.4578 | Val Loss: 1.3144
# ------------------------------
# Epoch 10/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.5860
# Train Acc: 0.5467 | Val Acc: 0.5844
# Train Loss: 1.4008 | Val Loss: 1.3322
# ------------------------------
# Epoch 11/100
# LR: 3.00e-04
# Early Counter: 1 | Best Val Acc: 0.5860
# Train Acc: 0.5386 | Val Acc: 0.5990
# Train Loss: 1.4160 | Val Loss: 1.2885
# ------------------------------
# Epoch 12/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.5990
# Train Acc: 0.5411 | Val Acc: 0.5422
# Train Loss: 1.4123 | Val Loss: 1.3843
# ------------------------------
# Epoch 13/100
# LR: 3.00e-04
# Early Counter: 1 | Best Val Acc: 0.5990
# Train Acc: 0.5913 | Val Acc: 0.6055
# Train Loss: 1.3458 | Val Loss: 1.2542
# ------------------------------
# Epoch 14/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.6055
# Train Acc: 0.6197 | Val Acc: 0.6282
# Train Loss: 1.2957 | Val Loss: 1.2329
# ------------------------------
# Epoch 15/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.6282
# Train Acc: 0.5968 | Val Acc: 0.6023
# Train Loss: 1.3247 | Val Loss: 1.2819
# ------------------------------
# Epoch 16/100
# LR: 3.00e-04
# Early Counter: 1 | Best Val Acc: 0.6282
# Train Acc: 0.5969 | Val Acc: 0.6201
# Train Loss: 1.3236 | Val Loss: 1.2828
# ------------------------------
# Epoch 17/100
# LR: 3.00e-04
# Early Counter: 2 | Best Val Acc: 0.6282
# Train Acc: 0.6386 | Val Acc: 0.5974
# Train Loss: 1.2557 | Val Loss: 1.3521
# ------------------------------
# Epoch 18/100
# LR: 3.00e-04
# Early Counter: 3 | Best Val Acc: 0.6282
# Train Acc: 0.6415 | Val Acc: 0.6136
# Train Loss: 1.2548 | Val Loss: 1.2323
# ------------------------------
# Epoch 19/100
# LR: 3.00e-04
# Early Counter: 4 | Best Val Acc: 0.6282
# Train Acc: 0.6520 | Val Acc: 0.5698
# Train Loss: 1.2404 | Val Loss: 1.3962
# ------------------------------
# Epoch 20/100
# LR: 3.00e-04
# Early Counter: 5 | Best Val Acc: 0.6282
# Train Acc: 0.6638 | Val Acc: 0.5925
# Train Loss: 1.2351 | Val Loss: 1.3291
# ------------------------------
# Epoch 21/100
# LR: 3.00e-04
# Early Counter: 6 | Best Val Acc: 0.6282
# Train Acc: 0.6884 | Val Acc: 0.6039
# Train Loss: 1.1836 | Val Loss: 1.2799
# ------------------------------
# Epoch 22/100
# LR: 6.00e-05
# Early Counter: 7 | Best Val Acc: 0.6282
# Train Acc: 0.7452 | Val Acc: 0.6364
# Train Loss: 1.0866 | Val Loss: 1.2555
# ------------------------------
# Epoch 23/100
# LR: 6.00e-05
# Early Counter: 0 | Best Val Acc: 0.6364
# Train Acc: 0.7281 | Val Acc: 0.6591
# Train Loss: 1.1246 | Val Loss: 1.1905
# ------------------------------
# Epoch 24/100
# LR: 6.00e-05
# Early Counter: 0 | Best Val Acc: 0.6591
# Train Acc: 0.7340 | Val Acc: 0.6607
# Train Loss: 1.1129 | Val Loss: 1.1973
# ------------------------------
# Epoch 25/100
# LR: 6.00e-05
# Early Counter: 0 | Best Val Acc: 0.6607
# Train Acc: 0.7802 | Val Acc: 0.6591
# Train Loss: 1.0222 | Val Loss: 1.2021
# ------------------------------
# Epoch 26/100
# LR: 6.00e-05
# Early Counter: 1 | Best Val Acc: 0.6607
# Train Acc: 0.7787 | Val Acc: 0.6705
# Train Loss: 1.0497 | Val Loss: 1.1780
# ------------------------------
# Epoch 27/100
# LR: 6.00e-05
# Early Counter: 0 | Best Val Acc: 0.6705
# Train Acc: 0.7859 | Val Acc: 0.6769
# Train Loss: 1.0321 | Val Loss: 1.1881
# ------------------------------
# Epoch 28/100
# LR: 6.00e-05
# Early Counter: 0 | Best Val Acc: 0.6769
# Train Acc: 0.8047 | Val Acc: 0.6623
# Train Loss: 0.9979 | Val Loss: 1.2055
# ------------------------------
# Epoch 29/100
# LR: 6.00e-05
# Early Counter: 1 | Best Val Acc: 0.6769
# Train Acc: 0.7712 | Val Acc: 0.6802
# Train Loss: 1.0693 | Val Loss: 1.1896
# ------------------------------
# Epoch 30/100
# LR: 1.20e-05
# Early Counter: 0 | Best Val Acc: 0.6802
# Train Acc: 0.7818 | Val Acc: 0.6672
# Train Loss: 1.0563 | Val Loss: 1.2037
# ------------------------------
# Epoch 31/100
# LR: 1.20e-05
# Early Counter: 1 | Best Val Acc: 0.6802
# Train Acc: 0.8272 | Val Acc: 0.6688
# Train Loss: 0.9739 | Val Loss: 1.1922
# ------------------------------
# Epoch 32/100
# LR: 1.20e-05
# Early Counter: 2 | Best Val Acc: 0.6802
# Train Acc: 0.8124 | Val Acc: 0.6705
# Train Loss: 0.9889 | Val Loss: 1.1983
# ------------------------------
# Epoch 33/100
# LR: 1.20e-05
# Early Counter: 3 | Best Val Acc: 0.6802
# Train Acc: 0.7942 | Val Acc: 0.6705
# Train Loss: 1.0128 | Val Loss: 1.1976
# ------------------------------
# Epoch 34/100
# LR: 2.40e-06
# Early Counter: 4 | Best Val Acc: 0.6802
# Train Acc: 0.8566 | Val Acc: 0.6591
# Train Loss: 0.9003 | Val Loss: 1.1963
# ------------------------------
# Epoch 35/100
# LR: 2.40e-06
# Early Counter: 5 | Best Val Acc: 0.6802
# Train Acc: 0.8349 | Val Acc: 0.6721
# Train Loss: 0.9435 | Val Loss: 1.1892
# ------------------------------
# Epoch 36/100
# LR: 2.40e-06
# Early Counter: 6 | Best Val Acc: 0.6802
# Train Acc: 0.8459 | Val Acc: 0.6705
# Train Loss: 0.9221 | Val Loss: 1.1892
# ------------------------------
# Epoch 37/100
# LR: 2.40e-06
# Early Counter: 7 | Best Val Acc: 0.6802
# Train Acc: 0.8092 | Val Acc: 0.6672
# Train Loss: 1.0113 | Val Loss: 1.2050
# ------------------------------
# Epoch 38/100
# LR: 4.80e-07
# Early Counter: 8 | Best Val Acc: 0.6802
# Train Acc: 0.8265 | Val Acc: 0.6623
# Train Loss: 0.9664 | Val Loss: 1.1967
# ------------------------------
# Epoch 39/100
# LR: 4.80e-07
# Early Counter: 9 | Best Val Acc: 0.6802
# Train Acc: 0.8208 | Val Acc: 0.6656
# Train Loss: 0.9783 | Val Loss: 1.1967
# ------------------------------
# Epoch 40/100
# LR: 4.80e-07
# Early Counter: 10 | Best Val Acc: 0.6802
# Train Acc: 0.7976 | Val Acc: 0.6688
# Train Loss: 1.0278 | Val Loss: 1.1970
# ------------------------------
# Epoch 41/100
# LR: 4.80e-07
# Early Counter: 11 | Best Val Acc: 0.6802
# Train Acc: 0.8094 | Val Acc: 0.6705
# Train Loss: 1.0039 | Val Loss: 1.1996
# ------------------------------
# Epoch 42/100
# LR: 9.60e-08
# Early Counter: 12 | Best Val Acc: 0.6802
# Train Acc: 0.8022 | Val Acc: 0.6591
# Train Loss: 1.0196 | Val Loss: 1.2083
# ------------------------------
# Epoch 43/100
# LR: 9.60e-08
# Early Counter: 13 | Best Val Acc: 0.6802
# Train Acc: 0.8049 | Val Acc: 0.6753
# Train Loss: 0.9944 | Val Loss: 1.1920
# ------------------------------
# Epoch 44/100
# LR: 9.60e-08
# Early Counter: 14 | Best Val Acc: 0.6802
# Train Acc: 0.8272 | Val Acc: 0.6558
# Train Loss: 0.9551 | Val Loss: 1.2103
# ------------------------------
# Early stopping

# %%
model.load_state_dict(best_weights)

val_loss, val_acc, y_true, y_pred = evaluate(model, val_loader)

# %%
precision, recall, f1, _ = precision_recall_fscore_support(
    y_true, y_pred, average='weighted'
)

mcc = matthews_corrcoef(y_true, y_pred)
bal_acc = balanced_accuracy_score(y_true, y_pred)

cm = confusion_matrix(y_true, y_pred)

report = classification_report(
    y_true,
    y_pred,
    target_names=class_names
)

results = {
    "accuracy": val_acc,
    "precision": precision,
    "recall": recall,
    "f1": f1,
    "mcc": mcc,
    "balanced_accuracy": bal_acc
}

print(results)
print(report)
# Out:
# {'accuracy': 0.6801948051948052, 'precision': 0.6771494600414782, 'recall': 0.6801948051948052, 'f1': 0.6748425967193666, 'mcc': 0.6093197907287172, 'balanced_accuracy': 0.6346100796038694}
#               precision    recall  f1-score   support
#
#     Bacteria       0.85      0.89      0.87       126
#        Fungi       0.61      0.68      0.65       139
#      Healthy       0.48      0.24      0.32        42
#     Nematode       0.64      0.64      0.64        11
#         Pest       0.52      0.54      0.53       112
#  Phytopthora       0.69      0.75      0.72        71
#        Virus       0.79      0.70      0.74       115
#
#     accuracy                           0.68       616
#    macro avg       0.65      0.63      0.64       616
# weighted avg       0.68      0.68      0.67       616

# %%
pd.DataFrame(history).to_csv(f"{OUTPUT_DIR}/history.csv", index=False)
pd.DataFrame([results]).to_csv(f"{OUTPUT_DIR}/summary.csv", index=False)

with open(f"{OUTPUT_DIR}/results.json","w") as f:
    json.dump(results,f,indent=4)

with open(f"{OUTPUT_DIR}/report.txt","w") as f:
    f.write(report)

# %%
plt.figure(figsize=(12,5))
plt.plot(history["train_loss"], label="Train")
plt.plot(history["val_loss"], label="Val")
plt.legend()
plt.savefig(f"{OUTPUT_DIR}/loss_curve.png")
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.plot(history["train_acc"], label="Train")
plt.plot(history["val_acc"], label="Val")
plt.legend()
plt.savefig(f"{OUTPUT_DIR}/acc_curve.png")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    xticklabels=class_names,
    yticklabels=class_names
)
plt.savefig(f"{OUTPUT_DIR}/confusion_matrix.png")
plt.show()
