# %%
import os
import json
import time
import copy
import random
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
from torch.amp import autocast, GradScaler
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms
import torch.nn.functional as F

from sklearn.metrics import (
    accuracy_score,
    precision_recall_fscore_support,
    matthews_corrcoef,
    balanced_accuracy_score,
    confusion_matrix,
    classification_report
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
SEED = 2912

def seed_everything(seed=SEED):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

seed_everything()
torch.backends.cudnn.benchmark = True

# %%
DATASET_PATH = "../Dataset"
DATASET_NAME = "Mendeley_Dataset"

IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 100
LR = 3e-4
ACCUM_STEPS = 2
PATIENCE = 15
MIN_DELTA = 0.001

OUTPUT_DIR = f"../Results/{DATASET_NAME}/Model_9"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
def mixup_data(x, y, alpha=0.2):
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1.0

    batch_size = x.size(0)
    index = torch.randperm(batch_size, device=x.device)

    mixed_x = lam * x + (1 - lam) * x[index]
    y_a, y_b = y, y[index]

    return mixed_x, y_a, y_b, lam

# %%
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.8, 0.9)),
    transforms.RandomVerticalFlip(),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(40),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    transforms.ToTensor()
])

val_transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor()
])

# %%
full_dataset = datasets.ImageFolder(f"{DATASET_PATH}/{DATASET_NAME}")

class_names = full_dataset.classes
num_classes = len(class_names)

train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size

train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

train_dataset.dataset.transform = train_transform
val_dataset.dataset.transform = val_transform

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=4,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=4,
    pin_memory=True
)

print(class_names)
print(num_classes)
# Out:
# ['Bacteria', 'Fungi', 'Healthy', 'Nematode', 'Pest', 'Phytopthora', 'Virus']
# 7

# %%
import torch
import torch.nn as nn

class CrossAttentionCNN(nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        # Feature extractor
        self.conv1 = self._block(3, 16)
        self.conv2 = self._block(16, 32)
        self.conv3 = self._block(32, 64)
        self.conv4 = self._block(64, 128)

        # Project Conv2 to Conv4 dimension
        self.proj_c2 = nn.Conv2d(32, 128, kernel_size=1)

        # Cross Attention
        self.attn = nn.MultiheadAttention(
            embed_dim=128,
            num_heads=2,
            batch_first=True
        )

        self.gap = nn.AdaptiveAvgPool1d(1)

        # Lightweight classifier
        self.fc = nn.Sequential(
            nn.Linear(128, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(0.5)
        )

        self.classifier = nn.Linear(64, num_classes)

    def _block(self, in_c, out_c):
        return nn.Sequential(
            nn.Conv2d(in_c, out_c, 3, padding=1),
            nn.BatchNorm2d(out_c),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

    def forward(self, x):

        f1 = self.conv1(x)
        f2 = self.conv2(f1)
        f3 = self.conv3(f2)
        f4 = self.conv4(f3)

        # Align Conv2 to Conv4
        f2_proj = self.proj_c2(f2)

        # Match spatial size
        f2_proj = nn.functional.interpolate(
            f2_proj,
            size=f4.shape[-2:]
        )

        # Flatten to tokens
        q = f4.flatten(2).transpose(1, 2)
        kv = f2_proj.flatten(2).transpose(1, 2)

        # Cross Attention
        attn_out, _ = self.attn(q, kv, kv)

        pooled = attn_out.transpose(1, 2)
        pooled = self.gap(pooled).squeeze(-1)

        x = self.fc(pooled)

        return self.classifier(x)

# %%
model = CrossAttentionCNN(num_classes).to(device)

# %%
# Total parameters
total_params = sum(p.numel() for p in model.parameters())

# Trainable parameters
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"Total Parameters: {total_params:,}")
print(f"Trainable Parameters: {trainable_params:,}")
# Out:
# Total Parameters: 177,031
# Trainable Parameters: 177,031

# %%
from torchinfo import summary

summary(model, input_size=(1, 3, 224, 224))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CrossAttentionCNN                        [1, 7]                    --
# ├─Sequential: 1-1                        [1, 16, 112, 112]         --
# │    └─Conv2d: 2-1                       [1, 16, 224, 224]         448
# │    └─BatchNorm2d: 2-2                  [1, 16, 224, 224]         32
# │    └─ReLU: 2-3                         [1, 16, 224, 224]         --
# │    └─MaxPool2d: 2-4                    [1, 16, 112, 112]         --
# ├─Sequential: 1-2                        [1, 32, 56, 56]           --
# │    └─Conv2d: 2-5                       [1, 32, 112, 112]         4,640
# │    └─BatchNorm2d: 2-6                  [1, 32, 112, 112]         64
# │    └─ReLU: 2-7                         [1, 32, 112, 112]         --
# │    └─MaxPool2d: 2-8                    [1, 32, 56, 56]           --
# ├─Sequential: 1-3                        [1, 64, 28, 28]           --
# │    └─Conv2d: 2-9                       [1, 64, 56, 56]           18,496
# │    └─BatchNorm2d: 2-10                 [1, 64, 56, 56]           128
# │    └─ReLU: 2-11                        [1, 64, 56, 56]           --
# │    └─MaxPool2d: 2-12                   [1, 64, 28, 28]           --
# ├─Sequential: 1-4                        [1, 128, 14, 14]          --
# │    └─Conv2d: 2-13                      [1, 128, 28, 28]          73,856
# │    └─BatchNorm2d: 2-14                 [1, 128, 28, 28]          256
# │    └─ReLU: 2-15                        [1, 128, 28, 28]          --
# │    └─MaxPool2d: 2-16                   [1, 128, 14, 14]          --
# ├─Conv2d: 1-5                            [1, 128, 56, 56]          4,224
# ├─MultiheadAttention: 1-6                [1, 196, 128]             66,048
# ├─AdaptiveAvgPool1d: 1-7                 [1, 128, 1]               --
# ├─Sequential: 1-8                        [1, 64]                   --
# │    └─Linear: 2-17                      [1, 64]                   8,256
# │    └─BatchNorm1d: 2-18                 [1, 64]                   128
# │    └─ReLU: 2-19                        [1, 64]                   --
# │    └─Dropout: 2-20                     [1, 64]                   --
# ├─Linear: 1-9                            [1, 7]                    455
# ==========================================================================================
# Total params: 177,031
# Trainable params: 177,031
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 209.85
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 27.30
# Params size (MB): 0.44
# Estimated Total Size (MB): 28.34
# ==========================================================================================

# %%
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=LR,
    weight_decay=1e-4
)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=0.2,
    patience=3
)

scaler = GradScaler()

# %%
def evaluate(model, loader):
    model.eval()

    all_preds = []
    all_labels = []
    total_loss = 0

    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)

            with autocast(device_type=device.type):
                outputs = model(images)
                loss = criterion(outputs, labels)

            total_loss += loss.item()

            preds = outputs.argmax(1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    acc = accuracy_score(all_labels, all_preds)

    return total_loss/len(loader), acc, all_labels, all_preds

# %%
history = {
    "train_loss": [],
    "val_loss": [],
    "train_acc": [],
    "val_acc": []
}

best_acc = 0
best_weights = copy.deepcopy(model.state_dict())
early_counter = 0

# %%
for epoch in range(EPOCHS):

    model.train()

    running_loss = 0
    correct = 0
    total = 0

    optimizer.zero_grad()

    for i, (images, labels) in enumerate(train_loader):

        images, labels = images.to(device), labels.to(device)

        # Apply MixUp
        mixed_images, targets_a, targets_b, lam = mixup_data(
            images,
            labels,
            alpha=0.2
        )

        with autocast(device_type=device.type):
            outputs = model(mixed_images)

            loss = (
                lam * criterion(outputs, targets_a)
                + (1 - lam) * criterion(outputs, targets_b)
            ) / ACCUM_STEPS

        scaler.scale(loss).backward()

        if (i+1) % ACCUM_STEPS == 0:
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()

        running_loss += loss.item()*ACCUM_STEPS

        preds = outputs.argmax(1)

        correct += (
            lam * (preds == targets_a).sum().item()
            + (1 - lam) * (preds == targets_b).sum().item()
        )

        total += labels.size(0)
    
    if len(train_loader) % ACCUM_STEPS != 0:
        scaler.step(optimizer)
        scaler.update()
        optimizer.zero_grad()

    train_loss = running_loss / len(train_loader)
    train_acc = correct / total

    val_loss, val_acc, _, _ = evaluate(model, val_loader)

    scheduler.step(val_loss)

    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_acc"].append(train_acc)
    history["val_acc"].append(val_acc)
    
    print(f"Epoch {epoch+1}/{EPOCHS}")
    print(f"LR: {optimizer.param_groups[0]['lr']:.2e}")
    print(f"Early Counter: {early_counter} | Best Val Acc: {best_acc:.4f}")
    print(f"Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f}")
    print(f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")
    print("-"*30)

    if val_acc > best_acc + MIN_DELTA:
        best_acc = val_acc
        best_weights = copy.deepcopy(model.state_dict())
        torch.save(best_weights, f"{OUTPUT_DIR}/best_model.pth")
        early_counter = 0
    else:
        early_counter += 1

    if early_counter >= PATIENCE:
        print("Early stopping")
        break
# Out:
# Epoch 1/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.0000
# Train Acc: 0.2520 | Val Acc: 0.4221
# Train Loss: 1.8931 | Val Loss: 1.7213
# ------------------------------
# Epoch 2/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.4221
# Train Acc: 0.3544 | Val Acc: 0.4643
# Train Loss: 1.7535 | Val Loss: 1.5897
# ------------------------------
# Epoch 3/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.4643
# Train Acc: 0.3680 | Val Acc: 0.4692
# Train Loss: 1.7003 | Val Loss: 1.5338
# ------------------------------
# Epoch 4/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.4692
# Train Acc: 0.4072 | Val Acc: 0.4984
# Train Loss: 1.6440 | Val Loss: 1.4995
# ------------------------------
# Epoch 5/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.4984
# Train Acc: 0.4181 | Val Acc: 0.4692
# Train Loss: 1.6161 | Val Loss: 1.5345
# ------------------------------
# Epoch 6/100
# LR: 3.00e-04
# Early Counter: 1 | Best Val Acc: 0.4984
# Train Acc: 0.4202 | Val Acc: 0.4383
# Train Loss: 1.5996 | Val Loss: 1.5552
# ------------------------------
# Epoch 7/100
# LR: 3.00e-04
# Early Counter: 2 | Best Val Acc: 0.4984
# Train Acc: 0.4378 | Val Acc: 0.5000
# Train Loss: 1.5765 | Val Loss: 1.4974
# ------------------------------
# Epoch 8/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.5000
# Train Acc: 0.4446 | Val Acc: 0.4334
# Train Loss: 1.5532 | Val Loss: 1.6948
# ------------------------------
# Epoch 9/100
# LR: 3.00e-04
# Early Counter: 1 | Best Val Acc: 0.5000
# Train Acc: 0.4700 | Val Acc: 0.5487
# Train Loss: 1.5345 | Val Loss: 1.4009
# ------------------------------
# Epoch 10/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.5487
# Train Acc: 0.4915 | Val Acc: 0.5455
# Train Loss: 1.4836 | Val Loss: 1.4210
# ------------------------------
# Epoch 11/100
# LR: 3.00e-04
# Early Counter: 1 | Best Val Acc: 0.5487
# Train Acc: 0.4925 | Val Acc: 0.5536
# Train Loss: 1.4977 | Val Loss: 1.3949
# ------------------------------
# Epoch 12/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.5536
# Train Acc: 0.4919 | Val Acc: 0.5487
# Train Loss: 1.5008 | Val Loss: 1.3722
# ------------------------------
# Epoch 13/100
# LR: 3.00e-04
# Early Counter: 1 | Best Val Acc: 0.5536
# Train Acc: 0.5052 | Val Acc: 0.5649
# Train Loss: 1.4734 | Val Loss: 1.3558
# ------------------------------
# Epoch 14/100
# LR: 3.00e-04
# Early Counter: 0 | Best Val Acc: 0.5649
# Train Acc: 0.5270 | Val Acc: 0.5422
# Train Loss: 1.4397 | Val Loss: 1.3888
# ------------------------------
# Epoch 15/100
# LR: 3.00e-04
# Early Counter: 1 | Best Val Acc: 0.5649
# Train Acc: 0.5148 | Val Acc: 0.5179
# Train Loss: 1.4483 | Val Loss: 1.4490
# ------------------------------
# Epoch 16/100
# LR: 3.00e-04
# Early Counter: 2 | Best Val Acc: 0.5649
# Train Acc: 0.5158 | Val Acc: 0.5179
# Train Loss: 1.4599 | Val Loss: 1.4561
# ------------------------------
# Epoch 17/100
# LR: 6.00e-05
# Early Counter: 3 | Best Val Acc: 0.5649
# Train Acc: 0.5415 | Val Acc: 0.5162
# Train Loss: 1.4106 | Val Loss: 1.4911
# ------------------------------
# Epoch 18/100
# LR: 6.00e-05
# Early Counter: 4 | Best Val Acc: 0.5649
# Train Acc: 0.5382 | Val Acc: 0.6104
# Train Loss: 1.4097 | Val Loss: 1.2761
# ------------------------------
# Epoch 19/100
# LR: 6.00e-05
# Early Counter: 0 | Best Val Acc: 0.6104
# Train Acc: 0.5619 | Val Acc: 0.5974
# Train Loss: 1.3713 | Val Loss: 1.2731
# ------------------------------
# Epoch 20/100
# LR: 6.00e-05
# Early Counter: 1 | Best Val Acc: 0.6104
# Train Acc: 0.5554 | Val Acc: 0.6055
# Train Loss: 1.3883 | Val Loss: 1.2598
# ------------------------------
# Epoch 21/100
# LR: 6.00e-05
# Early Counter: 2 | Best Val Acc: 0.6104
# Train Acc: 0.5833 | Val Acc: 0.6201
# Train Loss: 1.3452 | Val Loss: 1.2528
# ------------------------------
# Epoch 22/100
# LR: 6.00e-05
# Early Counter: 0 | Best Val Acc: 0.6201
# Train Acc: 0.6048 | Val Acc: 0.6315
# Train Loss: 1.3191 | Val Loss: 1.2562
# ------------------------------
# Epoch 23/100
# LR: 6.00e-05
# Early Counter: 0 | Best Val Acc: 0.6315
# Train Acc: 0.5719 | Val Acc: 0.6331
# Train Loss: 1.3739 | Val Loss: 1.2490
# ------------------------------
# Epoch 24/100
# LR: 6.00e-05
# Early Counter: 0 | Best Val Acc: 0.6331
# Train Acc: 0.5681 | Val Acc: 0.6266
# Train Loss: 1.3820 | Val Loss: 1.2564
# ------------------------------
# Epoch 25/100
# LR: 6.00e-05
# Early Counter: 1 | Best Val Acc: 0.6331
# Train Acc: 0.5859 | Val Acc: 0.6169
# Train Loss: 1.3487 | Val Loss: 1.2555
# ------------------------------
# Epoch 26/100
# LR: 6.00e-05
# Early Counter: 2 | Best Val Acc: 0.6331
# Train Acc: 0.5925 | Val Acc: 0.6266
# Train Loss: 1.3445 | Val Loss: 1.2445
# ------------------------------
# Epoch 27/100
# LR: 6.00e-05
# Early Counter: 3 | Best Val Acc: 0.6331
# Train Acc: 0.5829 | Val Acc: 0.6331
# Train Loss: 1.3396 | Val Loss: 1.2403
# ------------------------------
# Epoch 28/100
# LR: 6.00e-05
# Early Counter: 4 | Best Val Acc: 0.6331
# Train Acc: 0.6001 | Val Acc: 0.6299
# Train Loss: 1.3248 | Val Loss: 1.2368
# ------------------------------
# Epoch 29/100
# LR: 6.00e-05
# Early Counter: 5 | Best Val Acc: 0.6331
# Train Acc: 0.5875 | Val Acc: 0.6364
# Train Loss: 1.3455 | Val Loss: 1.2623
# ------------------------------
# Epoch 30/100
# LR: 6.00e-05
# Early Counter: 0 | Best Val Acc: 0.6364
# Train Acc: 0.5920 | Val Acc: 0.6396
# Train Loss: 1.3451 | Val Loss: 1.2284
# ------------------------------
# Epoch 31/100
# LR: 6.00e-05
# Early Counter: 0 | Best Val Acc: 0.6396
# Train Acc: 0.6161 | Val Acc: 0.6396
# Train Loss: 1.3078 | Val Loss: 1.2366
# ------------------------------
# Epoch 32/100
# LR: 6.00e-05
# Early Counter: 1 | Best Val Acc: 0.6396
# Train Acc: 0.5944 | Val Acc: 0.6071
# Train Loss: 1.3287 | Val Loss: 1.2850
# ------------------------------
# Epoch 33/100
# LR: 6.00e-05
# Early Counter: 2 | Best Val Acc: 0.6396
# Train Acc: 0.6024 | Val Acc: 0.6461
# Train Loss: 1.3247 | Val Loss: 1.2360
# ------------------------------
# Epoch 34/100
# LR: 1.20e-05
# Early Counter: 0 | Best Val Acc: 0.6461
# Train Acc: 0.6343 | Val Acc: 0.6218
# Train Loss: 1.2757 | Val Loss: 1.2440
# ------------------------------
# Epoch 35/100
# LR: 1.20e-05
# Early Counter: 1 | Best Val Acc: 0.6461
# Train Acc: 0.6277 | Val Acc: 0.6526
# Train Loss: 1.2686 | Val Loss: 1.2230
# ------------------------------
# Epoch 36/100
# LR: 1.20e-05
# Early Counter: 0 | Best Val Acc: 0.6526
# Train Acc: 0.6254 | Val Acc: 0.6429
# Train Loss: 1.2745 | Val Loss: 1.2266
# ------------------------------
# Epoch 37/100
# LR: 1.20e-05
# Early Counter: 1 | Best Val Acc: 0.6526
# Train Acc: 0.6054 | Val Acc: 0.6575
# Train Loss: 1.3123 | Val Loss: 1.2199
# ------------------------------
# Epoch 38/100
# LR: 1.20e-05
# Early Counter: 0 | Best Val Acc: 0.6575
# Train Acc: 0.6233 | Val Acc: 0.6461
# Train Loss: 1.2899 | Val Loss: 1.2133
# ------------------------------
# Epoch 39/100
# LR: 1.20e-05
# Early Counter: 1 | Best Val Acc: 0.6575
# Train Acc: 0.6097 | Val Acc: 0.6558
# Train Loss: 1.2984 | Val Loss: 1.2107
# ------------------------------
# Epoch 40/100
# LR: 1.20e-05
# Early Counter: 2 | Best Val Acc: 0.6575
# Train Acc: 0.6033 | Val Acc: 0.6494
# Train Loss: 1.3257 | Val Loss: 1.2166
# ------------------------------
# Epoch 41/100
# LR: 1.20e-05
# Early Counter: 3 | Best Val Acc: 0.6575
# Train Acc: 0.6136 | Val Acc: 0.6542
# Train Loss: 1.3049 | Val Loss: 1.2147
# ------------------------------
# Epoch 42/100
# LR: 1.20e-05
# Early Counter: 4 | Best Val Acc: 0.6575
# Train Acc: 0.6136 | Val Acc: 0.6510
# Train Loss: 1.3011 | Val Loss: 1.2255
# ------------------------------
# Epoch 43/100
# LR: 2.40e-06
# Early Counter: 5 | Best Val Acc: 0.6575
# Train Acc: 0.6188 | Val Acc: 0.6526
# Train Loss: 1.3008 | Val Loss: 1.2181
# ------------------------------
# Epoch 44/100
# LR: 2.40e-06
# Early Counter: 6 | Best Val Acc: 0.6575
# Train Acc: 0.6259 | Val Acc: 0.6607
# Train Loss: 1.2784 | Val Loss: 1.2135
# ------------------------------
# Epoch 45/100
# LR: 2.40e-06
# Early Counter: 0 | Best Val Acc: 0.6607
# Train Acc: 0.6228 | Val Acc: 0.6542
# Train Loss: 1.2785 | Val Loss: 1.2045
# ------------------------------
# Epoch 46/100
# LR: 2.40e-06
# Early Counter: 1 | Best Val Acc: 0.6607
# Train Acc: 0.6361 | Val Acc: 0.6558
# Train Loss: 1.2756 | Val Loss: 1.2126
# ------------------------------
# Epoch 47/100
# LR: 2.40e-06
# Early Counter: 2 | Best Val Acc: 0.6607
# Train Acc: 0.6269 | Val Acc: 0.6591
# Train Loss: 1.2767 | Val Loss: 1.2141
# ------------------------------
# Epoch 48/100
# LR: 2.40e-06
# Early Counter: 3 | Best Val Acc: 0.6607
# Train Acc: 0.6040 | Val Acc: 0.6542
# Train Loss: 1.3414 | Val Loss: 1.2157
# ------------------------------
# Epoch 49/100
# LR: 4.80e-07
# Early Counter: 4 | Best Val Acc: 0.6607
# Train Acc: 0.6281 | Val Acc: 0.6558
# Train Loss: 1.2907 | Val Loss: 1.2113
# ------------------------------
# Epoch 50/100
# LR: 4.80e-07
# Early Counter: 5 | Best Val Acc: 0.6607
# Train Acc: 0.6101 | Val Acc: 0.6575
# Train Loss: 1.3163 | Val Loss: 1.2165
# ------------------------------
# Epoch 51/100
# LR: 4.80e-07
# Early Counter: 6 | Best Val Acc: 0.6607
# Train Acc: 0.6201 | Val Acc: 0.6575
# Train Loss: 1.3017 | Val Loss: 1.2177
# ------------------------------
# Epoch 52/100
# LR: 4.80e-07
# Early Counter: 7 | Best Val Acc: 0.6607
# Train Acc: 0.6343 | Val Acc: 0.6526
# Train Loss: 1.2688 | Val Loss: 1.2175
# ------------------------------
# Epoch 53/100
# LR: 9.60e-08
# Early Counter: 8 | Best Val Acc: 0.6607
# Train Acc: 0.6364 | Val Acc: 0.6558
# Train Loss: 1.2631 | Val Loss: 1.2156
# ------------------------------
# Epoch 54/100
# LR: 9.60e-08
# Early Counter: 9 | Best Val Acc: 0.6607
# Train Acc: 0.6168 | Val Acc: 0.6494
# Train Loss: 1.3002 | Val Loss: 1.2124
# ------------------------------
# Epoch 55/100
# LR: 9.60e-08
# Early Counter: 10 | Best Val Acc: 0.6607
# Train Acc: 0.6331 | Val Acc: 0.6542
# Train Loss: 1.2815 | Val Loss: 1.2136
# ------------------------------
# Epoch 56/100
# LR: 9.60e-08
# Early Counter: 11 | Best Val Acc: 0.6607
# Train Acc: 0.6268 | Val Acc: 0.6542
# Train Loss: 1.2934 | Val Loss: 1.2117
# ------------------------------
# Epoch 57/100
# LR: 1.92e-08
# Early Counter: 12 | Best Val Acc: 0.6607
# Train Acc: 0.6143 | Val Acc: 0.6575
# Train Loss: 1.3162 | Val Loss: 1.2190
# ------------------------------
# Epoch 58/100
# LR: 1.92e-08
# Early Counter: 13 | Best Val Acc: 0.6607
# Train Acc: 0.6052 | Val Acc: 0.6510
# Train Loss: 1.3069 | Val Loss: 1.2233
# ------------------------------
# Epoch 59/100
# LR: 1.92e-08
# Early Counter: 14 | Best Val Acc: 0.6607
# Train Acc: 0.6097 | Val Acc: 0.6542
# Train Loss: 1.3094 | Val Loss: 1.2223
# ------------------------------
# Early stopping

# %%
model.load_state_dict(best_weights)

val_loss, val_acc, y_true, y_pred = evaluate(model, val_loader)

# %%
precision, recall, f1, _ = precision_recall_fscore_support(
    y_true, y_pred, average='weighted'
)

mcc = matthews_corrcoef(y_true, y_pred)
bal_acc = balanced_accuracy_score(y_true, y_pred)

cm = confusion_matrix(y_true, y_pred)

report = classification_report(
    y_true,
    y_pred,
    target_names=class_names
)

results = {
    "accuracy": val_acc,
    "precision": precision,
    "recall": recall,
    "f1": f1,
    "mcc": mcc,
    "balanced_accuracy": bal_acc
}

print(results)
print(report)
# Out:
# {'accuracy': 0.6607142857142857, 'precision': 0.6753093630307787, 'recall': 0.6607142857142857, 'f1': 0.6487263382957386, 'mcc': 0.5857075116158758, 'balanced_accuracy': 0.6266760792189483}
#               precision    recall  f1-score   support
#
#     Bacteria       0.78      0.92      0.85       126
#        Fungi       0.57      0.61      0.59       139
#      Healthy       0.71      0.12      0.20        42
#     Nematode       0.53      0.82      0.64        11
#         Pest       0.50      0.62      0.55       112
#  Phytopthora       0.77      0.61      0.68        71
#        Virus       0.80      0.70      0.74       115
#
#     accuracy                           0.66       616
#    macro avg       0.67      0.63      0.61       616
# weighted avg       0.68      0.66      0.65       616

# %%
pd.DataFrame(history).to_csv(f"{OUTPUT_DIR}/history.csv", index=False)
pd.DataFrame([results]).to_csv(f"{OUTPUT_DIR}/summary.csv", index=False)

with open(f"{OUTPUT_DIR}/results.json","w") as f:
    json.dump(results,f,indent=4)

with open(f"{OUTPUT_DIR}/report.txt","w") as f:
    f.write(report)

# %%
plt.figure(figsize=(12,5))
plt.plot(history["train_loss"], label="Train")
plt.plot(history["val_loss"], label="Val")
plt.legend()
plt.savefig(f"{OUTPUT_DIR}/loss_curve.png")
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.plot(history["train_acc"], label="Train")
plt.plot(history["val_acc"], label="Val")
plt.legend()
plt.savefig(f"{OUTPUT_DIR}/acc_curve.png")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    xticklabels=class_names,
    yticklabels=class_names
)
plt.savefig(f"{OUTPUT_DIR}/confusion_matrix.png")
plt.show()
